# %% [markdown]
# <a href="https://colab.research.google.com/github/gitflai/MinicursoFLAIDataScienceNaCopa/blob/main/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Minicurso FLAI Data Science na Copa do Mundo Qatar 2022 ⚽**

# %%
#instalaçao das bibliotecas (opicional)
#import pip
#pip.main(["install","pandas==1.5.2","numpy==1.23.5","openpyxl==3.0.10","streamlit==1.15.1","scipy==1.9.3"])

# %%
import pandas as pd
import numpy as np
import random
from scipy.stats import poisson

selecoes = pd.read_excel('dados/DadosCopaDoMundoQatar2022.xlsx', sheet_name ='selecoes', index_col = 0)
jogos = pd.read_excel('dados/DadosCopaDoMundoQatar2022.xlsx', sheet_name ='jogos')

# %%
selecoes.head()
# Out:
#            Grupo GrupoNumero NomeEmIngles  PosiçãoRankingFIFA  ValorDeMercado  \
# Seleção
# Catar          A          A1        Qatar                  48           18.33
# Equador        A          A2      Ecuador                  44          125.80
# Senegal        A          A3      Senegal                  18          286.50
# Holanda        A          A4  Netherlands                   8          455.75
# Inglaterra     B          B1      England                   5         1360.00
#
#             PontosRankingFIFA Confederação  Copas   JogadorDestaque  \
# Seleção
# Catar                    1442          AFC      0        Almoez Ali
# Equador                  1464         UEFA      0  Pervis Estupiñán
# Senegal                  1585          CAF      0        Sadio Mané
# Holanda                  1679         UEFA      0   Virgil Van Dijk
# Inglaterra               1737         UEFA      1        Harry Kane
#
#                                           FotoJogadorDestaque  \
# Seleção
# Catar       https://github.com/ricardorocha86/PrevisaoEspo...
# Equador     https://github.com/ricardorocha86/PrevisaoEspo...
# Senegal     https://github.com/ricardorocha86/PrevisaoEspo...
# Holanda     https://github.com/ricardorocha86/PrevisaoEspo...
# Inglaterra  https://github.com/ricardorocha86/PrevisaoEspo...
#
#                                           LinkBandeiraPequena  \
# Seleção
# Catar       https://cloudinary.fifa.com/api/v3/picture/fla...
# Equador     https://cloudinary.fifa.com/api/v3/picture/fla...
# Senegal     https://cloudinary.fifa.com/api/v3/picture/fla...
# Holanda     https://cloudinary.fifa.com/api/v3/picture/fla...
# Inglaterra  https://cloudinary.fifa.com/api/v3/picture/fla...
#
#                                            LinkBandeiraGrande
# Seleção
# Catar       https://flagdownload.com/wp-content/uploads/Fl...
# Equador     https://flagdownload.com/wp-content/uploads/Fl...
# Senegal     https://flagdownload.com/wp-content/uploads/Fl...
# Holanda     https://flagdownload.com/wp-content/uploads/Fl...
# Inglaterra  https://flagdownload.com/wp-content/uploads/Fl...

# %%
jogos.head()
# Out:
#         data      hora grupo seleção1 seleção2         estádio
# 0 2022-11-21  07:00:00     A  Senegal  Holanda      AL THUMAMA
# 1 2022-11-21  13:00:00     A    Catar  Equador         AL KHOR
# 2 2022-11-25  10:00:00     A    Catar  Senegal      AL THUMAMA
# 3 2022-11-25  13:00:00     A  Holanda  Equador  INTER. KHALIFA
# 4 2022-11-29  12:00:00     A  Holanda    Catar         AL KHOR

# %%
fifa = selecoes['PontosRankingFIFA']
fifa
# Out:
# Seleção
# Catar             1442
# Equador           1464
# Senegal           1585
# Holanda           1679
# Inglaterra        1737
# Irã               1559
# Estados Unidos    1635
# País de Gales     1582
# Argentina         1771
# Arábia Saudita    1436
# México            1650
# Polônia           1546
# França            1765
# Dinamarca         1665
# Tunísia           1508
# Austrália         1484
# Espanha           1717
# Alemanha          1659
# Japão             1555
# Costa Rica        1500
# Bélgica           1822
# Canadá            1474
# Marrocos          1558
# Croácia           1632
# Brasil            1838
# Sérvia            1550
# Suíça             1621
# Camarões          1485
# Portugal          1679
# Gana              1393
# Uruguai           1641
# Coreia do Sul     1526
# Name: PontosRankingFIFA, dtype: int64

# %%
a, b = min(fifa), max(fifa) 
fa, fb = 0.15, 1 
b1 = (fb - fa)/(b-a) 
b0 = fb - b*b1
forca = b0 + b1*fifa 

forca.sort_values(ascending = False)
# Out:
# Seleção
# Brasil            1.000000
# Bélgica           0.969438
# Argentina         0.872022
# França            0.860562
# Inglaterra        0.807079
# Espanha           0.768876
# Holanda           0.696292
# Portugal          0.696292
# Dinamarca         0.669551
# Alemanha          0.658090
# México            0.640899
# Uruguai           0.623708
# Estados Unidos    0.612247
# Croácia           0.606517
# Suíça             0.585506
# Senegal           0.516742
# País de Gales     0.511011
# Irã               0.467079
# Marrocos          0.465169
# Japão             0.459438
# Sérvia            0.449888
# Polônia           0.442247
# Coreia do Sul     0.404045
# Tunísia           0.369663
# Costa Rica        0.354382
# Camarões          0.325730
# Austrália         0.323820
# Canadá            0.304719
# Equador           0.285618
# Catar             0.243596
# Arábia Saudita    0.232135
# Gana              0.150000
# Name: PontosRankingFIFA, dtype: float64

# %%
def Resultado(gols1, gols2):
    if gols1 > gols2:
        res = 'V'
    if gols1 < gols2:
        res = 'D' 
    if gols1 == gols2:
        res = 'E'       
    return res

def MediasPoisson(selecao1, selecao2):
    forca1 = forca[selecao1]
    forca2 = forca[selecao2] 
    mgols = 2.75
    l1 = mgols*forca1/(forca1 + forca2)
    l2 = mgols*forca2/(forca1 + forca2)
    return [l1, l2]
    
def Distribuicao(media):
    probs = []
    for i in range(7):
        probs.append(poisson.pmf(i,media))
    probs.append(1-sum(probs))
    return pd.Series(probs, index = ['0', '1', '2', '3', '4', '5', '6', '7+'])

def ProbabilidadesPartida(selecao1, selecao2):
    l1, l2 = MediasPoisson(selecao1, selecao2)
    d1, d2 = Distribuicao(l1), Distribuicao(l2)  
    matriz = np.outer(d1, d2)    #   Monta a matriz de probabilidades

    vitoria = np.tril(matriz).sum()-np.trace(matriz)    #Soma a triangulo inferior
    derrota = np.triu(matriz).sum()-np.trace(matriz)    #Soma a triangulo superior
    probs = np.around([vitoria, 1-(vitoria+derrota), derrota], 3)
    probsp = [f'{100*i:.1f}%' for i in probs]

    nomes = ['0', '1', '2', '3', '4', '5', '6', '7+']
    matriz = pd.DataFrame(matriz, columns = nomes, index = nomes)
    matriz.index = pd.MultiIndex.from_product([[selecao1], matriz.index])
    matriz.columns = pd.MultiIndex.from_product([[selecao2], matriz.columns]) 
    output = {'seleção1': selecao1, 'seleção2': selecao2, 
             'f1': forca[selecao1], 'f2': forca[selecao2], 
             'media1': l1, 'media2': l2, 
             'probabilidades': probsp, 'matriz': matriz}
    return output

def Pontos(gols1, gols2):
    rst = Resultado(gols1, gols2)
    if rst == 'V':
        pontos1, pontos2 = 3, 0
    if rst == 'E':
        pontos1, pontos2 = 1, 1
    if rst == 'D':
        pontos1, pontos2 = 0, 3
    return pontos1, pontos2, rst


def Jogo(selecao1, selecao2):
    l1, l2 = MediasPoisson(selecao1, selecao2)
    gols1 = int(np.random.poisson(lam = l1, size = 1))
    gols2 = int(np.random.poisson(lam = l2, size = 1))
    saldo1 = gols1 - gols2
    saldo2 = -saldo1
    pontos1, pontos2, result = Pontos(gols1, gols2)
    placar = '{}x{}'.format(gols1, gols2)
    return [gols1, gols2, saldo1, saldo2, pontos1, pontos2, result, placar]

# %%
def JogoMataMata(selecao1, selecao2): 
    jogo = Jogo(selecao1, selecao2)
    resultado = jogo[6]
    if resultado == 'V':
        return selecao1
    elif resultado == 'D':
        return selecao2
    else:
        return random.sample([selecao1, selecao2], 1)[0]

# %%
Jogo('Brasil', 'França')
# Out:
# [2, 2, 0, 0, 1, 1, 'E', '2x2']

# %%
JogoMataMata('Brasil', 'França')
# Out:
# 'Brasil'

# %%
ProbabilidadesPartida('Brasil', 'Gana')
# Out:
# {'seleção1': 'Brasil',
#  'seleção2': 'Gana',
#  'f1': 1.0,
#  'f2': 0.1499999999999999,
#  'media1': 2.3913043478260874,
#  'media2': 0.35869565217391286,
#  'probabilidades': ['82.8%', '13.2%', '4.0%'],
#  'matriz':                Gana                                                        \
#                    0         1         2         3         4             5
#  Brasil 0   0.063928  0.022931  0.004113  0.000492  0.000044  3.163294e-06
#         1   0.152871  0.054834  0.009834  0.001176  0.000105  7.564398e-06
#         2   0.182781  0.065563  0.011759  0.001406  0.000126  9.044388e-06
#         3   0.145695  0.052260  0.009373  0.001121  0.000100  7.209295e-06
#         4   0.087100  0.031242  0.005603  0.000670  0.000060  4.309905e-06
#         5   0.041657  0.014942  0.002680  0.000320  0.000029  2.061259e-06
#         6   0.016602  0.005955  0.001068  0.000128  0.000011  8.215162e-07
#         7+  0.007954  0.002853  0.000512  0.000061  0.000005  3.935894e-07
#
#
#                        6            7+
#  Brasil 0   1.891099e-07  1.014286e-08
#         1   4.522194e-07  2.425467e-08
#         2   5.406971e-07  2.900015e-08
#         3   4.309905e-07  2.311606e-08
#         4   2.576573e-07  1.381939e-08
#         5   1.232274e-07  6.609272e-09
#         6   4.911238e-08  2.634130e-09
#         7+  2.352980e-08  1.262015e-09  }

# %% [markdown]
# ---
# ## Tarefa 1: **Prever os Jogos da Copa!**

# %%
jogos['Vitória'] = None
jogos['Empate'] = None
jogos['Derrota'] = None

for i in range(jogos.shape[0]):
    selecao1 = jogos['seleção1'][i]
    selecao2 = jogos['seleção2'][i]
    v, e, d = ProbabilidadesPartida(selecao1, selecao2)['probabilidades']
    jogos.at[i,'Vitória'] = v
    jogos.at[i,'Empate'] = e
    jogos.at[i,'Derrota'] = d

jogos.to_excel('dados/outputEstimativasJogosCopa.xlsx', index = False)
jogos
# Out:
#          data      hora grupo        seleção1        seleção2         estádio  \
# 0  2022-11-21  07:00:00     A         Senegal         Holanda      AL THUMAMA
# 1  2022-11-21  13:00:00     A           Catar         Equador         AL KHOR
# 2  2022-11-25  10:00:00     A           Catar         Senegal      AL THUMAMA
# 3  2022-11-25  13:00:00     A         Holanda         Equador  INTER. KHALIFA
# 4  2022-11-29  12:00:00     A         Holanda           Catar         AL KHOR
# 5  2022-11-29  12:00:00     A         Equador         Senegal  INTER. KHALIFA
# 6  2022-11-21  10:00:00     B      Inglaterra             Irã  INTER. KHALIFA
# 7  2022-11-21  16:00:00     B  Estados Unidos   País de Gales       AL RAYYAN
# 8  2022-11-25  07:00:00     B   País de Gales             Irã       AL RAYYAN
# 9  2022-11-25  16:00:00     B      Inglaterra  Estados Unidos         AL KHOR
# 10 2022-11-29  16:00:00     B   País de Gales      Inglaterra       AL RAYYAN
# 11 2022-11-29  16:00:00     B             Irã  Estados Unidos      AL THUMAMA
# 12 2022-11-22  07:00:00     C       Argentina  Arábia Saudita   CID. EDUCAÇÃO
# 13 2022-11-22  13:00:00     C          México         Polônia       AL WAKRAH
# 14 2022-11-26  10:00:00     C         Polônia  Arábia Saudita   CID. EDUCAÇÃO
# 15 2022-11-26  16:00:00     C       Argentina          México  NAC. DE LUSAIL
# 16 2022-11-30  16:00:00     C         Polônia       Argentina   PORTO DE DOHA
# 17 2022-11-30  16:00:00     C  Arábia Saudita          México  NAC. DE LUSAIL
# 18 2022-11-22  10:00:00     D       Dinamarca         Tunísia   CID. EDUCAÇÃO
# 19 2022-11-22  16:00:00     D          França       Austrália       AL WAKRAH
# 20 2022-11-26  07:00:00     D         Tunísia       Austrália       AL WAKRAH
# 21 2022-11-26  13:00:00     D          França       Dinamarca   PORTO DE DOHA
# 22 2022-11-30  12:00:00     D         Tunísia          França   CID. EDUCAÇÃO
# 23 2022-11-30  12:00:00     D       Austrália       Dinamarca       AL WAKRAH
# 24 2022-11-23  10:00:00     E        Alemanha           Japão  INTER. KHALIFA
# 25 2022-11-23  13:00:00     E         Espanha      Costa Rica      AL THUMAMA
# 26 2022-11-27  07:00:00     E           Japão      Costa Rica       AL RAYYAN
# 27 2022-11-27  16:00:00     E         Espanha        Alemanha         AL KHOR
# 28 2022-12-01  16:00:00     E           Japão         Espanha  INTER. KHALIFA
# 29 2022-12-01  16:00:00     E      Costa Rica        Alemanha         AL KHOR
# 30 2022-11-23  07:00:00     F        Marrocos         Croácia         AL KHOR
# 31 2022-11-23  16:00:00     F         Bélgica          Canadá       AL RAYYAN
# 32 2022-11-27  10:00:00     F         Bélgica        Marrocos      AL THUMAMA
# 33 2022-11-27  13:00:00     F         Croácia          Canadá   INTE. KHALIFA
# 34 2022-12-01  12:00:00     F         Croácia         Bélgica       AL RAYYAN
# 35 2022-12-01  12:00:00     F          Canadá        Marrocos      AL THUMAMA
# 36 2022-11-24  07:00:00     G           Suíça        Camarões       AL WAKRAH
# 37 2022-11-24  16:00:00     G          Brasil          Sérvia     NAC. LUSAIL
# 38 2022-11-28  07:00:00     G        Camarões          Sérvia       AL WAKRAH
# 39 2022-11-28  13:00:00     G          Brasil           Suíça   PORTO DE DOHA
# 40 2022-12-02  16:00:00     G        Camarões          Brasil     NAC. LUSAIL
# 41 2022-12-02  16:00:00     G          Sérvia           Suíça   PORTO DE DOHA
# 42 2022-11-24  10:00:00     H         Uruguai   Coreia do Sul   CID. EDUCAÇÃO
# 43 2022-11-24  13:00:00     H        Portugal            Gana   PORTO DE DOHA
# 44 2022-11-28  10:00:00     H   Coreia do Sul            Gana   CID. EDUCAÇÃO
# 45 2022-11-28  16:00:00     H        Portugal         Uruguai     NAC. LUSAIL
# 46 2022-12-02  12:00:00     H   Coreia do Sul        Portugal   CID. EDUCAÇÃO
# 47 2022-12-02  12:00:00     H            Gana         Uruguai       AL WAKRAH
#
#    Vitória Empate Derrota
# 0    28.3%  24.9%   46.8%
# 1    32.3%  25.4%   42.3%
# 2    17.2%  22.1%   60.6%
# 3    64.4%  21.0%   14.6%
# 4    68.4%  19.6%   12.0%
# 5    20.7%  23.3%   56.0%
# 6    54.6%  23.6%   21.8%
# 7    43.0%  25.3%   31.7%
# 8    40.1%  25.5%   34.4%
# 9    46.1%  25.0%   28.9%
# 10   24.0%  24.2%   51.8%
# 11   29.1%  25.0%   45.9%
# 12   74.2%  17.3%    8.5%
# 13   49.1%  24.6%   26.3%
# 14   57.5%  22.9%   19.5%
# 15   47.1%  24.9%   28.0%
# 16   18.8%  22.7%   58.5%
# 17   12.5%  19.9%   67.5%
# 18   56.0%  23.3%   20.7%
# 19   66.6%  20.3%   13.1%
# 20   41.4%  25.4%   33.1%
# 21   45.3%  25.1%   29.6%
# 22   15.4%  21.4%   63.2%
# 23   17.8%  22.3%   59.9%
# 24   48.7%  24.7%   26.6%
# 25   61.3%  22.0%   16.8%
# 26   45.5%  25.1%   29.4%
# 27   42.2%  25.4%   32.4%
# 28   22.6%  23.8%   53.6%
# 29   20.1%  23.1%   56.8%
# 30   29.2%  25.1%   45.7%
# 31   70.8%  18.7%   10.5%
# 32   60.1%  22.3%   17.6%
# 33   58.8%  22.6%   18.6%
# 34   23.7%  24.1%   52.2%
# 35   24.9%  24.4%   50.7%
# 36   55.8%  23.4%   20.8%
# 37   61.9%  21.8%   16.3%
# 38   27.6%  24.8%   47.6%
# 39   54.2%  23.7%   22.1%
# 40   11.0%  19.0%   70.0%
# 41   29.3%  25.1%   45.7%
# 42   51.1%  24.3%   24.6%
# 43   77.9%  15.6%    6.4%
# 44   66.9%  20.2%   12.9%
# 45   40.7%  25.5%   33.8%
# 46   21.8%  23.6%   54.5%
# 47    7.4%  16.5%   76.1%

# %% [markdown]
# ## Tarefa 2: **Simular a Copa do Mundo Inteira!**

# %%
def JogosGrupo(dados, grupo): 
    
    times = list(dados.loc[dados['Grupo']==grupo].index)

    time1, time2, time3, time4 = times  # nome dos times 

    pt1, pt2, pt3, pt4 = 0, 0, 0, 0
    gp1, gp2, gp3, gp4 = 0, 0, 0, 0
    sg1, sg2, sg3, sg4 = 0, 0, 0, 0

    jogo1 = Jogo(time1, time2)
    jogo2 = Jogo(time3, time4)

    jogo3 = Jogo(time1, time3)
    jogo4 = Jogo(time2, time4)

    jogo5 = Jogo(time1, time4)
    jogo6 = Jogo(time2, time3)

    gp1, gp2, sg1, sg2, pt1, pt2 = gp1 + jogo1[0], gp2 + jogo1[1], sg1 + jogo1[2], sg2 + jogo1[3], pt1 + jogo1[4], pt2 + jogo1[5]
    gp3, gp4, sg3, sg4, pt3, pt4 = gp3 + jogo2[0], gp4 + jogo2[1], sg3 + jogo2[2], sg4 + jogo2[3], pt3 + jogo2[4], pt4 + jogo2[5]
    gp1, gp3, sg1, sg3, pt1, pt3 = gp1 + jogo3[0], gp3 + jogo3[1], sg1 + jogo3[2], sg3 + jogo3[3], pt1 + jogo3[4], pt3 + jogo3[5]
    gp2, gp4, sg2, sg4, pt2, pt4 = gp2 + jogo4[0], gp4 + jogo4[1], sg2 + jogo4[2], sg4 + jogo4[3], pt2 + jogo4[4], pt4 + jogo4[5]
    gp1, gp4, sg1, sg4, pt1, pt4 = gp1 + jogo5[0], gp4 + jogo5[1], sg1 + jogo5[2], sg4 + jogo5[3], pt1 + jogo5[4], pt4 + jogo5[5]
    gp2, gp3, sg2, sg3, pt2, pt3 = gp2 + jogo6[0], gp3 + jogo6[1], sg2 + jogo6[2], sg3 + jogo6[3], pt2 + jogo6[4], pt3 + jogo6[5]

    partidas = [ time1 + ' x ' + time2, 
                 time3 + ' x ' + time4,
                 time1 + ' x ' + time3, 
                 time2 + ' x ' + time4,
                 time1 + ' x ' + time4,
                 time2 + ' x ' + time3]

    resultados = [ jogo1[6], jogo2[6], jogo3[6], jogo4[6], jogo5[6], jogo6[6] ]
    placares = [ jogo1[-1], jogo2[-1], jogo3[-1], jogo4[-1], jogo5[-1], jogo6[-1] ] 
    cols = ['Pontos', 'Saldo de Gols', 'Gols Pró']
    tab = pd.DataFrame([[pt1, pt2, pt3, pt4], [sg1, sg2, sg3, sg4], [gp1, gp2, gp3, gp4]], index = cols, columns = times).transpose()
    
    tab = tab.sort_values(['Pontos', 'Saldo de Gols', 'Gols Pró'], ascending = False)
    tab['Posição'] = [1, 2, 3, 4]

    jogos = pd.DataFrame([partidas, placares, resultados]).transpose()
    jogos.columns = ['Partida', 'Placar', 'Resultado']

    return [tab, jogos]

# %%
exemplo = JogosGrupo(selecoes, 'G')
exemplo
# Out:
# [          Pontos  Saldo de Gols  Gols Pró  Posição
#  Brasil         9              5         8        1
#  Camarões       4              0         6        2
#  Suíça          4             -1         2        3
#  Sérvia         0             -4         2        4,
#               Partida Placar Resultado
#  0    Brasil x Sérvia    1x0         V
#  1   Suíça x Camarões    0x0         E
#  2     Brasil x Suíça    3x1         V
#  3  Sérvia x Camarões    2x4         D
#  4  Brasil x Camarões    4x2         V
#  5     Sérvia x Suíça    0x1         D]

# %%
exemplo[0]
# Out:
#           Pontos  Saldo de Gols  Gols Pró  Posição
# Brasil         9              5         8        1
# Camarões       4              0         6        2
# Suíça          4             -1         2        3
# Sérvia         0             -4         2        4

# %%
exemplo[1]
# Out:
#              Partida Placar Resultado
# 0    Brasil x Sérvia    1x0         V
# 1   Suíça x Camarões    0x0         E
# 2     Brasil x Suíça    3x1         V
# 3  Sérvia x Camarões    2x4         D
# 4  Brasil x Camarões    4x2         V
# 5     Sérvia x Suíça    0x1         D

# %%
def SimulaCopa(dados):
    cols = ['1st', '2nd', '3rd', '4th', 'Oitavas', 'Quartas', 'Semis', 'Final', 'Campeão']
    n = dados.shape[0]
    m = len(cols)
    aux = np.array(np.zeros(n*m).reshape(n, m))
    info = pd.DataFrame(aux, columns = cols, index = dados.index) 
    info = info.astype(int)

    top16 = []  
    for i in list('ABCDEFGH'):
        a = JogosGrupo(dados, i)[0] 
        top16 += a.index[:2].tolist()
        anomes = a.index.to_list() 
        info.at[anomes[0], '1st'] = 1
        info.at[anomes[1], '2nd'] = 1
        info.at[anomes[2], '3rd'] = 1
        info.at[anomes[3], '4th'] = 1

    qf1 = JogoMataMata(top16[0], top16[3])   #A1 x B2
    qf2 = JogoMataMata(top16[2], top16[1])   #B1 x A2
    qf3 = JogoMataMata(top16[4], top16[7])   #C1 x D2 
    qf4 = JogoMataMata(top16[6], top16[5])   #D1 x C2
    qf5 = JogoMataMata(top16[8], top16[11])  #E1 x F2
    qf6 = JogoMataMata(top16[10], top16[9])  #F1 x E2
    qf7 = JogoMataMata(top16[12], top16[15]) #G1 x H2
    qf8 = JogoMataMata(top16[14], top16[13]) #H1 x G2

    top8 = [qf1, qf2, qf3, qf4, qf5, qf6, qf7, qf8]


    sf1 = JogoMataMata(qf1, qf3)
    sf2 = JogoMataMata(qf2, qf4) 
    sf3 = JogoMataMata(qf5, qf7) 
    sf4 = JogoMataMata(qf6, qf8) 

    top4 = [sf1, sf2, sf3, sf4]

    f1 = JogoMataMata(sf1, sf3) 
    f2 = JogoMataMata(sf2, sf4) 
    top2 = [f1, f2]

    top1 = JogoMataMata(f1, f2)

    info.at[top16, 'Oitavas'] = 1
    info.at[top8, 'Quartas'] = 1
    info.at[top4, 'Semis'] = 1
    info.at[top2, 'Final'] = 1
    info.at[top1, 'Campeão'] = 1

    return info

# %%
    cols = ['1st', '2nd', '3rd', '4th', 'Oitavas', 'Quartas', 'Semis', 'Final', 'Campeão']
    n = selecoes.shape[0]
    m = len(cols)
    aux = np.array(np.zeros(n*m).reshape(n, m))
    info = pd.DataFrame(aux, columns = cols, index = selecoes.index) 
    info = info.astype(int)

    top16 = []  
    for i in list('ABCDEFGH'):
        a = JogosGrupo(selecoes, i)[0] 
        top16 += a.index[:2].tolist()
        anomes = a.index.to_list() 
        info.at[anomes[0], '1st'] = 1
        info.at[anomes[1], '2nd'] = 1
        info.at[anomes[2], '3rd'] = 1
        info.at[anomes[3], '4th'] = 1

    qf1 = JogoMataMata(top16[0], top16[3])   #A1 x B2
    qf2 = JogoMataMata(top16[2], top16[1])   #B1 x A2
    qf3 = JogoMataMata(top16[4], top16[7])   #C1 x D2 
    qf4 = JogoMataMata(top16[6], top16[5])   #D1 x C2
    qf5 = JogoMataMata(top16[8], top16[11])  #E1 x F2
    qf6 = JogoMataMata(top16[10], top16[9])  #F1 x E2
    qf7 = JogoMataMata(top16[12], top16[15]) #G1 x H2
    qf8 = JogoMataMata(top16[14], top16[13]) #H1 x G2

    top8 = [qf1, qf2, qf3, qf4, qf5, qf6, qf7, qf8]


    sf1 = JogoMataMata(qf1, qf3)
    sf2 = JogoMataMata(qf2, qf4) 
    sf3 = JogoMataMata(qf5, qf7) 
    sf4 = JogoMataMata(qf6, qf8) 

    top4 = [sf1, sf2, sf3, sf4]

    f1 = JogoMataMata(sf1, sf3) 
    f2 = JogoMataMata(sf2, sf4) 
    top2 = [f1, f2]

    top1 = JogoMataMata(f1, f2)

    info[top16,'Oitavas'] = 1
    
    info
# Out:
#                 1st  2nd  3rd  4th  Oitavas  Quartas  Semis  Final  Campeão
# Seleção
# Catar             0    0    1    0        0        0      0      0        0
# Equador           0    0    0    1        0        0      0      0        0
# Senegal           0    1    0    0        0        0      0      0        0
# Holanda           1    0    0    0        0        0      0      0        0
# Inglaterra        1    0    0    0        0        0      0      0        0
# Irã               0    0    0    1        0        0      0      0        0
# Estados Unidos    0    1    0    0        0        0      0      0        0
# País de Gales     0    0    1    0        0        0      0      0        0
# Argentina         1    0    0    0        0        0      0      0        0
# Arábia Saudita    0    0    0    1        0        0      0      0        0
# México            0    0    1    0        0        0      0      0        0
# Polônia           0    1    0    0        0        0      0      0        0
# França            1    0    0    0        0        0      0      0        0
# Dinamarca         0    0    0    1        0        0      0      0        0
# Tunísia           0    1    0    0        0        0      0      0        0
# Austrália         0    0    1    0        0        0      0      0        0
# Espanha           0    1    0    0        0        0      0      0        0
# Alemanha          1    0    0    0        0        0      0      0        0
# Japão             0    0    1    0        0        0      0      0        0
# Costa Rica        0    0    0    1        0        0      0      0        0
# Bélgica           1    0    0    0        0        0      0      0        0
# Canadá            0    0    0    1        0        0      0      0        0
# Marrocos          0    1    0    0        0        0      0      0        0
# Croácia           0    0    1    0        0        0      0      0        0
# Brasil            1    0    0    0        0        0      0      0        0
# Sérvia            0    1    0    0        0        0      0      0        0
# Suíça             0    0    0    1        0        0      0      0        0
# Camarões          0    0    1    0        0        0      0      0        0
# Portugal          0    1    0    0        0        0      0      0        0
# Gana              0    0    0    1        0        0      0      0        0
# Uruguai           1    0    0    0        0        0      0      0        0
# Coreia do Sul     0    0    1    0        0        0      0      0        0

# %%
SimulaCopa(selecoes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['Senegal', 'Holanda', 'Inglaterra', 'Estados Unidos', 'Argentina', 'Polônia', 'França', 'Austrália', 'Espanha', 'Alemanha', 'Bélgica', 'Croácia', 'Sérvia', 'Brasil', 'Portugal', 'Uruguai']' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:4209, in DataFrame._set_value(self, index, col, value, takeable)
#    4208     icol = self.columns.get_loc(col)
# -> 4209     iindex = self.index.get_loc(index)
#    4210 self._mgr.column_setitem(icol, iindex, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3810, in Index.get_loc(self, key, method, tolerance)
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
# -> 3810     self._check_indexing_error(key)
#    3811     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:5968, in Index._check_indexing_error(self, key)
#    5965 if not is_scalar(key):
#    5966     # if key is not a scalar, directly raise an error (the code below
#    5967     # would convert to numpy arrays and raise later any way) - GH29926
# -> 5968     raise InvalidIndexError(key)
#
# InvalidIndexError: ['Senegal', 'Holanda', 'Inglaterra', 'Estados Unidos', 'Argentina', 'Polônia', 'França', 'Austrália', 'Espanha', 'Alemanha', 'Bélgica', 'Croácia', 'Sérvia', 'Brasil', 'Portugal', 'Uruguai']
#
# The above exception was the direct cause of the following exception:
#
# InvalidIndexError                         Traceback (most recent call last)
# c:\Users\otavi\GitHub\FLAI - DataScienceNaCopa\Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb Célula: 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> SimulaCopa(selecoes)
#
# c:\Users\otavi\GitHub\FLAI - DataScienceNaCopa\Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb Célula: 22 in SimulaCopa(dados)
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X30sZmlsZQ%3D%3D?line=39'>40</a> top2 = [f1, f2]
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X30sZmlsZQ%3D%3D?line=41'>42</a> top1 = JogoMataMata(f1, f2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X30sZmlsZQ%3D%3D?line=43'>44</a> info.at[top16, 'Oitavas'] = 1
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X30sZmlsZQ%3D%3D?line=44'>45</a> info.at[top8, 'Quartas'] = 1
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X30sZmlsZQ%3D%3D?line=45'>46</a> info.at[top4, 'Semis'] = 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:2442, in _AtIndexer.__setitem__(self, key, value)
#    2439     self.obj.loc[key] = value
#    2440     return
# -> 2442 return super().__setitem__(key, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:2397, in _ScalarAccessIndexer.__setitem__(self, key, value)
#    2394 if len(key) != self.ndim:
#    2395     raise ValueError("Not enough indexers for scalar access (setting)!")
# -> 2397 self.obj._set_value(*key, value=value, takeable=self._takeable)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:4227, in DataFrame._set_value(self, index, col, value, takeable)
#    4222     self._item_cache.pop(col, None)
#    4224 except InvalidIndexError as ii_err:
#    4225     # GH48729: Seems like you are trying to assign a value to a
#    4226     # row when only scalar options are permitted
# -> 4227     raise InvalidIndexError(
#    4228         f"You can only assign a scalar value not a {type(value)}"
#    4229     ) from ii_err
#
# InvalidIndexError: You can only assign a scalar value not a <class 'int'>

# %%
SimulaCopa(selecoes).sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['Senegal', 'Holanda', 'Irã', 'Inglaterra', 'Argentina', 'México', 'França', 'Tunísia', 'Espanha', 'Alemanha', 'Bélgica', 'Croácia', 'Suíça', 'Brasil', 'Coreia do Sul', 'Uruguai']' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:4209, in DataFrame._set_value(self, index, col, value, takeable)
#    4208     icol = self.columns.get_loc(col)
# -> 4209     iindex = self.index.get_loc(index)
#    4210 self._mgr.column_setitem(icol, iindex, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3810, in Index.get_loc(self, key, method, tolerance)
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
# -> 3810     self._check_indexing_error(key)
#    3811     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:5968, in Index._check_indexing_error(self, key)
#    5965 if not is_scalar(key):
#    5966     # if key is not a scalar, directly raise an error (the code below
#    5967     # would convert to numpy arrays and raise later any way) - GH29926
# -> 5968     raise InvalidIndexError(key)
#
# InvalidIndexError: ['Senegal', 'Holanda', 'Irã', 'Inglaterra', 'Argentina', 'México', 'França', 'Tunísia', 'Espanha', 'Alemanha', 'Bélgica', 'Croácia', 'Suíça', 'Brasil', 'Coreia do Sul', 'Uruguai']
#
# The above exception was the direct cause of the following exception:
#
# InvalidIndexError                         Traceback (most recent call last)
# c:\Users\otavi\GitHub\FLAI - DataScienceNaCopa\Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb Célula: 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> SimulaCopa(selecoes).sum()
#
# c:\Users\otavi\GitHub\FLAI - DataScienceNaCopa\Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb Célula: 23 in SimulaCopa(selecoes)
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X31sZmlsZQ%3D%3D?line=39'>40</a> top2 = [f1, f2]
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X31sZmlsZQ%3D%3D?line=41'>42</a> top1 = JogoMataMata(f1, f2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X31sZmlsZQ%3D%3D?line=43'>44</a> info.at[top16, 'Oitavas'] = 1
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X31sZmlsZQ%3D%3D?line=44'>45</a> info.at[top8, 'Quartas'] = 1
#      <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X31sZmlsZQ%3D%3D?line=45'>46</a> info.at[top4, 'Semis'] = 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:2442, in _AtIndexer.__setitem__(self, key, value)
#    2439     self.obj.loc[key] = value
#    2440     return
# -> 2442 return super().__setitem__(key, value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:2397, in _ScalarAccessIndexer.__setitem__(self, key, value)
#    2394 if len(key) != self.ndim:
#    2395     raise ValueError("Not enough indexers for scalar access (setting)!")
# -> 2397 self.obj._set_value(*key, value=value, takeable=self._takeable)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:4227, in DataFrame._set_value(self, index, col, value, takeable)
#    4222     self._item_cache.pop(col, None)
#    4224 except InvalidIndexError as ii_err:
#    4225     # GH48729: Seems like you are trying to assign a value to a
#    4226     # row when only scalar options are permitted
# -> 4227     raise InvalidIndexError(
#    4228         f"You can only assign a scalar value not a {type(value)}"
#    4229     ) from ii_err
#
# InvalidIndexError: You can only assign a scalar value not a <class 'int'>

# %%
def SimulacaoTotal(dados, S = 1000): 
    print('IA: "Iniciando simulação..."')
    info = SimulaCopa(dados)
    for i in range(S-1):
        info += SimulaCopa(dados)
        if (i+2)%(S/10) == 0:
            print('IA: "Simulações de Copas do Mundo: {:.0f}% completas'.format(100*((i+2)/S)))    
    print('IA: "Simulação Finalizada!"')
    return info.sort_values(by = 'Campeão', ascending = False)/S

# %%
S = 10000
sim = SimulacaoTotal(selecoes, S) 
sim.to_excel('dados/outputSimulaçõesCopaDoMundo.xlsx')
sim

# %% [markdown]
# ## Extraindo mais informações das simulações

# %%
etapas = pd.DataFrame()
etapas['Cair na 1ª Fase'] = 1 - sim['Oitavas']
etapas['Cair nas Oitavas'] = sim['Oitavas'] - sim['Quartas']
etapas['Cair nas Quartas'] = sim['Quartas'] - sim['Semis']
etapas['Cair nas Semis'] = sim['Semis'] - sim['Final']
etapas['Cair na Final'] = sim['Final']  -  sim['Campeão'] 
etapas['Ganhar a Final'] = sim['Campeão']  
etapas.to_excel('outputProbabilidadesPorEtapa.xlsx')
etapas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otavi\GitHub\FLAI - DataScienceNaCopa\Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb Célula: 27 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> etapas = pd.DataFrame()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> etapas['Cair na 1ª Fase'] = 1 - sim['Oitavas']
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> etapas['Cair nas Oitavas'] = sim['Oitavas'] - sim['Quartas']
#       <a href='vscode-notebook-cell:/c%3A/Users/otavi/GitHub/FLAI%20-%20DataScienceNaCopa/Minicurso_FLAI_Data_Science_na_Copa_do_Mundo_Qatar_2022.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> etapas['Cair nas Quartas'] = sim['Quartas'] - sim['Semis']
#
# NameError: name 'sim' is not defined

# %%
avanco = pd.DataFrame()
avanco['Avançar na 1ª Fase'] = sim['Oitavas']
avanco['Avançar nas Oitavas'] = sim['Quartas']/sim['Oitavas'] 
avanco['Avançar nas Quartas'] = sim['Semis']/sim['Quartas'] 
avanco['Avançar nas Semis'] = sim['Final']/sim['Semis'] 
avanco['Avançar na Final'] = sim['Campeão']/sim['Final']   
avanco.to_excel('outputAvançoPorEtapa.xlsx')
avanco
